# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
# Load the dataset
file_path = '../kc_house_data.csv'
kc_house_data = pd.read_csv(file_path)
kc_house_data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
#listing columns
kc_house_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # Column Names and descriptions for Kings County Data Set
# * **id** - unique identified for a house
# * **date   Date**-house was sold
# * **price Price** -  is prediction target
# * **bedrooms Number** -  of Bedrooms/House
# * **bathrooms Number** -  of bathrooms/bedrooms
# * **sqft_living square** -  footage of the home
# * **sqft_lot square** -  footage of the lot
# * **floors Total** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# ## EDA AND DATA CLEANING

# %%
kc_house_data.describe
# Out:
# <bound method NDFrame.describe of                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
# ...

# %%
kc_house_data.shape
# Out:
# (21597, 21)

# %% [markdown]
# Number of rows(observations): There are 21597 rows in the dataframe
#
# Number of columns(variables): There are 21 columns in the dataframe

# %%
kc_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
# Convert 'date' column to datetime format
kc_house_data['date'] = pd.to_datetime(kc_house_data['date'])

# %%
# Convert 'sqft_basement' column to numeric, forcing errors to NaN
kc_house_data['sqft_basement'] = pd.to_numeric(kc_house_data['sqft_basement'], errors='coerce')

# %%
kc_house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %% [markdown]
# #Handling Missing values

# %%
# Identify missing values in the dataset
missing_values = kc_house_data.isnull().sum()
print("Missing values before cleaning:\n", missing_values)
# Out:
# Missing values before cleaning:
#  id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     454
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#Separating Numeric and Non-Numeric Columns:
numeric_cols = kc_house_data.select_dtypes(include=['number']).columns
non_numeric_cols = kc_house_data.select_dtypes(exclude=['number']).columns

#handling missing values in numeric columns
kc_house_data[numeric_cols] = kc_house_data[numeric_cols].fillna(kc_house_data[numeric_cols].mean())

#handling missing values in nonnumeric columns
for col in non_numeric_cols:
    kc_house_data[col].fillna(kc_house_data[col].mode()[0], inplace=True)

# %%
# Checking the dataset again for any remaining missing values
remaining_missing_values = kc_house_data.isnull().sum()
print("Missing values after cleaning:\n", remaining_missing_values)
# Out:
# Missing values after cleaning:
#  id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Address outliers in 'bedrooms' column by capping at a reasonable maximum (e.g., 10 bedrooms)
kc_house_data['bedrooms'] = kc_house_data['bedrooms'].apply(lambda x: min(x, 10))

# %%
# Display the dataset info after cleaning
kc_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  float64
#  9   view           21597 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  float64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
# Save the cleaned data
cleaned_file_path = '../kc_house_data.csv'
kc_house_data.to_csv(cleaned_file_path, index=False)
print(f"Cleaned dataset saved to {cleaned_file_path}")
# Out:
# Cleaned dataset saved to ../kc_house_data.csv

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")
# Correlation heatmap
plt.figure(figsize=(12, 10))
corr_matrix = kc_house_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot the distribution of the target variable 'price'
plt.figure(figsize=(10, 6))
sns.histplot(kc_house_data['price'], kde=True, bins=50)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Feature Selection

# %%
# select most important features
df = kc_house_data[['sqft_living', 'grade', 'bathrooms', 'price']]

# %%
sns.pairplot(data=df)

# %% [markdown]
# # Data Cleaning

# %%
# Plotting box plots for each column
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Box plots of Selected Columns')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# from the above visualization outliers seems to be only present in the price column

# %% [markdown]
# Get the Outliers

# %%
# Calculate IQR for selected columns
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# sqft_living      1120.00
# grade               1.00
# bathrooms           0.75
# price          323000.00
# dtype: float64

# %%
# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Find outliers
outliers = ((df < lower_bound) | (df > upper_bound)).any(axis=1)

# Print indices of outliers
outlier_indices = df.index[outliers]

# %% [markdown]
# Remove the outliers

# %%
# droping all columns with outliers 
df = df.drop(outlier_indices)

# %% [markdown]
# Check for Duplicates

# %%
df.duplicated().sum()
# Out:
# 344

# %% [markdown]
# Dropping Duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# Rechecking Check for Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data analysis

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sqft_living', y='price', data=df)
plt.title('Square footage of the home vs Price of the House')
plt.xlabel('Average Number of Rooms')
plt.ylabel('Price of the House ($1000s)')
plt.show()

# %% [markdown]
# # Trend Observation:
#
# In the scatter plot of RM (average number of rooms per dwelling) against MEDV (median home value), you can observe a positive trend. As the average number of rooms (RM) increases, the median home value (MEDV) tends to increase as well.
#
# # Implication:
#
# This suggests that larger houses with more rooms generally command higher prices in the Boston housing market. Homebuyers may be willing to pay more for properties that offer more living space.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='grade', y='price', data=df)
plt.title('Square footage of the home vs Price of the House')
plt.xlabel('Overall grade given to the housing unit, based on King County grading system')
plt.ylabel('Price of the House ($1000s)')
plt.show()

# %% [markdown]
# *Trend Observation:* In the scatter plot of LSTAT (percentage of lower status population) against MEDV (median home value), you can observe a negative trend. Areas with higher percentages of lower-status population (LSTAT) tend to have lower median home values (MEDV).
#
# *Implication:* This suggests that socioeconomic factors play a significant role in determining housing prices. Areas with higher poverty rates or lower socioeconomic status may have more affordable housing options compared to more affluent areas.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='bathrooms', y='price', data=df)
plt.title('Square footage of the home vs Price of the House')
plt.xlabel('Number of bathrooms/bedrooms')
plt.ylabel('Price of the House ($1000s)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap show a strong positive correlation between RM and MEDV (dark red), indicating that larger houses tend to have higher prices.
#
# Conversely, it show's strong negative correlation between LSTAT and MEDV (dark blue), suggesting that higher percentages of lower-status population correlate with lower housing prices.
#
# Weak correlations (lighter shades) between PTRATIO, INDUS, and MEDV might suggest these factors have less direct influence on housing prices or more complex relationships.

# %% [markdown]
# # Data Preparations

# %%
x = df[['sqft_living', 'grade', 'bathrooms']]
x.head()
# Out:
#    sqft_living  grade  bathrooms
# 0         1180      7       1.00
# 1         2570      7       2.25
# 2          770      6       1.00
# 3         1960      7       3.00
# 4         1680      8       2.00

# %%
y = df['price']
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %% [markdown]
# Test Train Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Scale data

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Modeling

# %%
model = LinearRegression()

# %%
# training the model
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test_scaled)

# %%
df = pd.DataFrame({"true":y_test,"pred":y_pred})
df.head()
# Out:
#            true           pred
# 9138   583000.0  566627.350316
# 15636  247200.0  418411.870593
# 15125  390000.0  418045.151789
# 13403  360000.0  426820.031287
# 17914  428000.0  458994.040035

# %% [markdown]
# # Validation

# %% [markdown]
# validating models perfomance

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2  = r2_score(y_test,y_pred)

# %%
print("mse",mse)
print("mae",mae)
print("R2" ,r2)
# Out:
# mse 23147215022.37798
# mae 121084.09796034315
# R2 0.3791062656527667

# %% [markdown]
# # Conclusion

# %% [markdown]
# Objective 1:
